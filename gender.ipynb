# %%
import numpy as np
import pandas as pd
import csv

# %%
lenders = pd.read_csv("lenders.csv")

# %%
name_gender_dict ={}
with open('wgnd_noctry.csv', mode='r') as infile:
    name_gender = csv.reader(infile)
    for rows in name_gender:
        name_gender_dict.update({rows[0]:rows[1]})

# %%
gender = []
for name in lenders["DISPLAY_NAME"]:
    name_str = str(name).upper()
    if name_str in name_gender_dict:
        gender.append(name_gender_dict.get(name_str))
    else:
        gender.append(None)

# %%
lenders["GENDER"]=gender

# %%
lenders.to_csv("lenders_update.csv")

# %%
lenders
# Out:
#               PERMANENT_NAME DISPLAY_NAME  MAIN_PIC_ID CITY STATE  \
# 0               kathleen4308     kathleen          NaN  NaN   NaN
# 1             nicole23891330       NICOLE          NaN  NaN   NaN
# 2                  brent3930        Brent          NaN  NaN   NaN
# 3                ben29606920          Ben          NaN  NaN   NaN
# 4        christopher21948977  Christopher          NaN  NaN   NaN
# ...                      ...          ...          ...  ...   ...
# 1551185      barbara57918296      Barbara          NaN  NaN   NaN
# 1551186          karthik8359      Karthik          NaN  NaN   NaN
# 1551187             itay6584         Itay          NaN  NaN   NaN
# 1551188              paz3494          Paz          NaN  NaN   NaN
# 1551189            ronen3711        Ronen          NaN  NaN   NaN
#
#         COUNTRY_CODE  MEMBER_SINCE PERSONAL_URL OCCUPATION LOAN_BECAUSE  \
# 0                NaN    1611182552          NaN        NaN          NaN
# ...

# %%
lenders[lenders["GENDER"].isnull()]
# Out:
#               PERMANENT_NAME       DISPLAY_NAME  MAIN_PIC_ID CITY STATE  \
# 3                ben29606920                Ben          NaN  NaN   NaN
# 4        christopher21948977        Christopher          NaN  NaN   NaN
# 7                   sean4935               Sean          NaN  NaN   NaN
# 9              jerry66928656              Jerry          NaN  NaN   NaN
# 10                 kylie9815              Kylie          NaN  NaN   NaN
# ...                      ...                ...          ...  ...   ...
# 1551176          frances9776            Frances          NaN  NaN   NaN
# 1551178            jonas8427              Jonas     524703.0  NaN   NaN
# 1551182   romwaldorannie4591  Romwaldo (Rannie)          NaN  NaN   NaN
# 1551183              wei2311                Wei          NaN  NaN   NaN
# 1551188              paz3494                Paz          NaN  NaN   NaN
#
#         COUNTRY_CODE  MEMBER_SINCE PERSONAL_URL OCCUPATION LOAN_BECAUSE  \
# ...

# %%
name_gender_dict
